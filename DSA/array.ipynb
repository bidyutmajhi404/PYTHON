# %% [markdown]
# ## Take input in an array and then print it .

# %%
arr = list( map(int,input("Enter value of the array ").split()))
print(arr)
# Out:
# Enter value of the array  10 2 030 10
# [10, 2, 30, 10]
