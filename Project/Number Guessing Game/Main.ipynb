# %% [markdown]
# ## Number Guessing Game

# %%
import random

# %%
attempts = 7

def display_rules():
    print("WELLCOME TO NUMBER GUESSING GAME ! \n")
    print("I have Selected a number between 1 to 100.")
    print("You have 7 attempts to guess it . \n")
    
def play_game(number,attempt=1):
    if attempt > attempts:
        print("\n Game Over !")
        print("The correct number was:",number)
        return 
    guess = input(f"Attempt {attempt}/7 - Enter your guess:")

    try:
        guess=int(guess)
    except ValueError:
        print("Please enter a valid number . \n")
        return play_game(number,attempt)
    if guess < 1 or guess > 100:
        print("Please enter a number between 1 and 100.\n")
        return play_game(number,attempt)

    if guess < 1 or guess > 100:
        print("Plese enter a number between 1 to 100 .\n")
        return play_game(number,attempt)

    chek_guess=lambda x,y:"correct" if x==y else("low"if x<y else "high")
    result=chek_guess(guess,number)

    if result=="correct":
        print("\nCongrtulations ! you guessed the correct number !")
        print("You guessed it in ", attempt, "attempt(s).")
        return

    if result=="low":
        print("too low ! try a higher number .\n")
    else:
        print("Too high ! try a lower number .\n")
    play_game(number,attempt+1)

display_rules()
random_number=random.randint(1,100)
play_game(random_number)
# Out:
# WELLCOME TO NUMBER GUESSING GAME !
#
# I have Selected a number between 1 to 100.
# You have 7 attempts to guess it .
# Attempt 1/7 - Enter your guess: 10
# too low ! try a higher number .
# Attempt 2/7 - Enter your guess: 20
# too low ! try a higher number .
# Attempt 3/7 - Enter your guess: 30
# too low ! try a higher number .
# Attempt 4/7 - Enter your guess: 40
# Congrtulations ! you guessed the correct number !
# You guessed it in  4 attemptd(s).
